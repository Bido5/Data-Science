# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {'A': [1,2,None], 'B': [4,5,6]}
df = pd.DataFrame(data, index=['A', 'B','C'])
df
# Out:
#      A  B
# A  1.0  4
# B  2.0  5
# C  NaN  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A to C
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       3 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 72.0+ bytes

# %%
df.describe()
# Out:
#               A    B
# count  2.000000  3.0
# mean   1.500000  5.0
# std    0.707107  1.0
# min    1.000000  4.0
# 25%    1.250000  4.5
# 50%    1.500000  5.0
# 75%    1.750000  5.5
# max    2.000000  6.0

# %%
df.isnull()
# Out:
#        A      B
# A  False  False
# B  False  False
# C   True  False

# %%
df.isnull().sum()
# Out:
# A    1
# B    0
# dtype: int64

# %%
df.nunique()
# Out:
# A    2
# B    3
# dtype: int64

# %%
data = {'A': [1,3,3], 'B': [1,3,3]}
dfc = pd.DataFrame(data, index=['A', 'B','C'])
dfc
# Out:
#    A  B
# A  1  1
# B  3  3
# C  3  3

# %%
dfc.nunique()
# Out:
# A    2
# B    2
# dtype: int64

# %%
dfc.duplicated()
# Out:
# A    False
# B    False
# C     True
# dtype: bool

# %%
print(dfc['B'].std())
# Out:
# 1.1547005383792517

# %%
df.max()
# Out:
# A    2.0
# B    6.0
# dtype: float64

# %%
df.min()
# Out:
# A    1.0
# B    4.0
# dtype: float64

# %%
df.dropna()
# Out:
#      A  B
# A  1.0  4
# B  2.0  5

# %%
df
# Out:
#      A  B
# A  1.0  4
# B  2.0  5
# C  NaN  6

# %%
data = {'A': [1,2,None], 'B': [4,5,6]}
dfa = pd.DataFrame(data, index=['A', 'B','C'])
dfa
# Out:
#      A  B
# A  1.0  4
# B  2.0  5
# C  NaN  6

# %%
dfa.dropna(inplace=True) 
# use inplace to delete the row with 
# null/none/NaN from the original dataframe

# %%
dfa
# Out:
#      A  B
# A  1.0  4
# B  2.0  5

# %%
data = {'A': [1,2,None], 'B': [4,5,6]}
dfa = pd.DataFrame(data, index=['A', 'B','C'])
dfa
# Out:
#      A  B
# A  1.0  4
# B  2.0  5
# C  NaN  6

# %%
dfa.dropna(axis=1 ,inplace=True)
# use axis=1 (column) and inplace to delete the column 
# from on the original dataframe

# %%
dfa
# Out:
#    B
# A  4
# B  5
# C  6

# %%
names = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack',
         'Kevin', 'Lily', 'Mike', 'Nina', 'Oscar', 'Paul', 'Quincy', 'Rita', 'Sam', 'Tina']
classes = np.random.choice(['Class A', 'Class B', 'Class C'], size=20)


df = pd.DataFrame({
    'name': names,
    'age': np.random.randint(16, 18, size=20),  
    'class': classes,
    'physics': np.random.randint(40, 100, size=20),
    'math': np.random.randint(40, 100, size=20),  
    'chemistry': np.random.randint(40, 100, size=20),  
    'art': np.random.randint(40, 100, size=20)  
})


df
# Out:
#        name  age    class  physics  math  chemistry  art
# 0     Alice   17  Class B       45    72         46   67
# 1       Bob   17  Class A       42    96         96   67
# 2   Charlie   16  Class A       60    81         82   78
# 3     David   16  Class A       94    95         56   96
# 4       Eve   16  Class C       99    97         43   77
# 5     Frank   16  Class B       85    85         45   97
# 6     Grace   16  Class A       99    81         97   76
# 7    Hannah   17  Class A       74    69         86   66
# 8       Ivy   17  Class A       68    88         89   73
# 9      Jack   17  Class C       96    63         52   80
# 10    Kevin   17  Class C       96    74         78   57
# 11     Lily   16  Class B       55    60         80   70
# 12     Mike   16  Class B       60    59         76   82
# 13     Nina   17  Class A       89    58         54   87
# 14    Oscar   16  Class B       59    58         64   43
# ...

# %%
df.shape
# Out:
# (20, 7)

# %%
df.T
# Out:
#                 0        1        2        3        4        5        6   \
# name         Alice      Bob  Charlie    David      Eve    Frank    Grace
# age             17       17       16       16       16       16       16
# class      Class B  Class A  Class A  Class A  Class C  Class B  Class A
# physics         45       42       60       94       99       85       99
# math            72       96       81       95       97       85       81
# chemistry       46       96       82       56       43       45       97
# art             67       67       78       96       77       97       76
#
#                 7        8        9        10       11       12       13  \
# name        Hannah      Ivy     Jack    Kevin     Lily     Mike     Nina
# age             17       17       17       17       16       16       17
# class      Class A  Class A  Class C  Class C  Class B  Class B  Class A
# physics         74       68       96       96       55       60       89
# ...

# %%
df.empty
# Out:
# False

# %%
df
# Out:
#        name  age    class  physics  math  chemistry  art
# 0     Alice   17  Class B       45    72         46   67
# 1       Bob   17  Class A       42    96         96   67
# 2   Charlie   16  Class A       60    81         82   78
# 3     David   16  Class A       94    95         56   96
# 4       Eve   16  Class C       99    97         43   77
# 5     Frank   16  Class B       85    85         45   97
# 6     Grace   16  Class A       99    81         97   76
# 7    Hannah   17  Class A       74    69         86   66
# 8       Ivy   17  Class A       68    88         89   73
# 9      Jack   17  Class C       96    63         52   80
# 10    Kevin   17  Class C       96    74         78   57
# 11     Lily   16  Class B       55    60         80   70
# 12     Mike   16  Class B       60    59         76   82
# 13     Nina   17  Class A       89    58         54   87
# 14    Oscar   16  Class B       59    58         64   43
# ...

# %%
df.head(6)
# Out:
#       name  age    class  physics  math  chemistry  art
# 0    Alice   17  Class B       45    72         46   67
# 1      Bob   17  Class A       42    96         96   67
# 2  Charlie   16  Class A       60    81         82   78
# 3    David   16  Class A       94    95         56   96
# 4      Eve   16  Class C       99    97         43   77
# 5    Frank   16  Class B       85    85         45   97

# %%
df.tail(3)
# Out:
#     name  age    class  physics  math  chemistry  art
# 17  Rita   16  Class C       91    72         48   55
# 18   Sam   17  Class A       85    70         51   90
# 19  Tina   17  Class C       78    99         92   44

# %%
df[df['math']<70]
# Out:
#       name  age    class  physics  math  chemistry  art
# 7   Hannah   17  Class A       74    69         86   66
# 9     Jack   17  Class C       96    63         52   80
# 11    Lily   16  Class B       55    60         80   70
# 12    Mike   16  Class B       60    59         76   82
# 13    Nina   17  Class A       89    58         54   87
# 14   Oscar   16  Class B       59    58         64   43
# 15    Paul   16  Class A       80    48         95   69

# %%
df.describe()
# Out:
#              age    physics       math  chemistry        art
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   16.450000  74.900000  75.850000  70.550000  72.800000
# std     0.510418  19.533776  15.438418  19.435386  15.073853
# min    16.000000  42.000000  48.000000  43.000000  43.000000
# 25%    16.000000  59.750000  62.250000  51.750000  66.750000
# 50%    16.000000  79.000000  73.000000  77.000000  74.500000
# 75%    17.000000  91.750000  89.000000  86.750000  82.000000
# max    17.000000  99.000000  99.000000  97.000000  97.000000

# %%
print(df.loc[:, 'physics'])
# Out:
# 0     45
# 1     42
# 2     60
# 3     94
# 4     99
# 5     85
# 6     99
# 7     74
# 8     68
# 9     96
# 10    96
# 11    55
# 12    60
# 13    89
# 14    59
# 15    80
# 16    43
# 17    91
# 18    85
# 19    78
# Name: physics, dtype: int64

# %%
df.iloc[4]
# Out:
# name             Eve
# age               16
# class        Class C
# physics           99
# math              97
# chemistry         43
# art               77
# grade           79.0
# Name: 4, dtype: object

# %%
df.iloc[6:11]
# Out:
#       name  age    class  physics  math  chemistry  art  grade
# 6    Grace   16  Class A       99    81         97   76  88.25
# 7   Hannah   17  Class A       74    69         86   66  73.75
# 8      Ivy   17  Class A       68    88         89   73  79.50
# 9     Jack   17  Class C       96    63         52   80  72.75
# 10   Kevin   17  Class C       96    74         78   57  76.25

# %%
df.values
# Out:
# array([['Alice', 17, 'Class B', 75, 83, 73, 83],
#        ['Bob', 17, 'Class A', 89, 70, 70, 75],
#        ['Charlie', 17, 'Class B', 83, 87, 71, 52],
#        ['David', 17, 'Class B', 76, 90, 96, 44],
#        ['Eve', 17, 'Class C', 89, 80, 91, 84],
#        ['Frank', 17, 'Class C', 58, 66, 41, 40],
#        ['Grace', 16, 'Class A', 73, 99, 54, 82],
#        ['Hannah', 17, 'Class B', 72, 81, 65, 71],
#        ['Ivy', 16, 'Class C', 74, 63, 79, 41],
#        ['Jack', 16, 'Class A', 67, 96, 96, 67],
#        ['Kevin', 17, 'Class A', 79, 76, 71, 47],
#        ['Lily', 16, 'Class B', 81, 72, 55, 53],
#        ['Mike', 16, 'Class C', 64, 67, 88, 91],
#        ['Nina', 17, 'Class B', 94, 40, 58, 85],
#        ['Oscar', 16, 'Class B', 64, 72, 92, 58],
#        ['Paul', 17, 'Class A', 58, 95, 64, 68],
#        ['Quincy', 16, 'Class B', 64, 41, 75, 88],
#        ['Rita', 17, 'Class B', 73, 81, 52, 81],
#        ['Sam', 16, 'Class B', 75, 71, 80, 84],
# ...

# %%
df.size
# Out:
# 140

# %%
df.median(numeric_only=True) # cannot compute for non numeric
# Out:
# age          16.0
# physics      79.0
# math         73.0
# chemistry    77.0
# art          74.5
# dtype: float64

# %%
df.median(axis=1,numeric_only=True) 
#does not make sense here but we can compute for each row 
#the metrics of the columns
# Out:
# 0     46.0
# 1     67.0
# 2     78.0
# 3     94.0
# 4     77.0
# 5     85.0
# 6     81.0
# 7     69.0
# 8     73.0
# 9     63.0
# 10    74.0
# 11    60.0
# 12    60.0
# 13    58.0
# 14    58.0
# 15    69.0
# 16    81.0
# 17    55.0
# 18    70.0
# 19    78.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# age          16.45
# physics      74.90
# math         75.85
# chemistry    70.55
# art          72.80
# dtype: float64

# %%
df['grade'] = (df['physics'] + df['math'] + df['chemistry'] + df['art'])/4

# %%
df
# Out:
#        name  age    class  physics  math  chemistry  art  grade
# 0     Alice   17  Class B       45    72         46   67  57.50
# 1       Bob   17  Class A       42    96         96   67  75.25
# 2   Charlie   16  Class A       60    81         82   78  75.25
# 3     David   16  Class A       94    95         56   96  85.25
# 4       Eve   16  Class C       99    97         43   77  79.00
# 5     Frank   16  Class B       85    85         45   97  78.00
# 6     Grace   16  Class A       99    81         97   76  88.25
# 7    Hannah   17  Class A       74    69         86   66  73.75
# 8       Ivy   17  Class A       68    88         89   73  79.50
# 9      Jack   17  Class C       96    63         52   80  72.75
# 10    Kevin   17  Class C       96    74         78   57  76.25
# 11     Lily   16  Class B       55    60         80   70  66.25
# 12     Mike   16  Class B       60    59         76   82  69.25
# 13     Nina   17  Class A       89    58         54   87  72.00
# ...

# %%
df.sort_values(by="grade") 
# set inplace to true if we want the df to stay sorted
# Out:
#        name  age    class  physics  math  chemistry  art  grade
# 14    Oscar   16  Class B       59    58         64   43  56.00
# 0     Alice   17  Class B       45    72         46   67  57.50
# 11     Lily   16  Class B       55    60         80   70  66.25
# 17     Rita   16  Class C       91    72         48   55  66.50
# 12     Mike   16  Class B       60    59         76   82  69.25
# 13     Nina   17  Class A       89    58         54   87  72.00
# 9      Jack   17  Class C       96    63         52   80  72.75
# 15     Paul   16  Class A       80    48         95   69  73.00
# 7    Hannah   17  Class A       74    69         86   66  73.75
# 18      Sam   17  Class A       85    70         51   90  74.00
# 16   Quincy   16  Class A       43    92         81   82  74.50
# 2   Charlie   16  Class A       60    81         82   78  75.25
# 1       Bob   17  Class A       42    96         96   67  75.25
# 10    Kevin   17  Class C       96    74         78   57  76.25
# ...

# %%
df[df['grade']>95]
# Out:
# Empty DataFrame
# Columns: [name, age, class, physics, math, chemistry, art, grade]
# Index: []

# %%
df[df['grade']>80]
# Out:
#     name  age    class  physics  math  chemistry  art  grade
# 3  David   16  Class A       94    95         56   96  85.25
# 6  Grace   16  Class A       99    81         97   76  88.25

# %%
df[df['grade']>80].sort_values('grade')
# Out:
#     name  age    class  physics  math  chemistry  art  grade
# 3  David   16  Class A       94    95         56   96  85.25
# 6  Grace   16  Class A       99    81         97   76  88.25

# %%
df[df['grade']<60]
# Out:
#      name  age    class  physics  math  chemistry  art  grade
# 0   Alice   17  Class B       45    72         46   67   57.5
# 14  Oscar   16  Class B       59    58         64   43   56.0

# %%
df[df['grade']<60].sort_values('grade')
# Out:
#      name  age    class  physics  math  chemistry  art  grade
# 14  Oscar   16  Class B       59    58         64   43   56.0
# 0   Alice   17  Class B       45    72         46   67   57.5

# %%
df.groupby('class').mean(numeric_only=True)
# Out:
#           age  physics  math  chemistry   art   grade
# class
# Class A  16.5     73.4  77.8       78.7  78.4  77.075
# Class B  16.2     60.8  66.8       62.2  71.8  65.400
# Class C  16.6     92.0  81.0       62.6  62.6  74.550

# %%
df.groupby('physics').mean(numeric_only=True)
# Out:
#           age  math  chemistry   art   grade
# physics
# 42       17.0  96.0       96.0  67.0  75.250
# 43       16.0  92.0       81.0  82.0  74.500
# 45       17.0  72.0       46.0  67.0  57.500
# 55       16.0  60.0       80.0  70.0  66.250
# 59       16.0  58.0       64.0  43.0  56.000
# 60       16.0  70.0       79.0  80.0  72.250
# 68       17.0  88.0       89.0  73.0  79.500
# 74       17.0  69.0       86.0  66.0  73.750
# 78       17.0  99.0       92.0  44.0  78.250
# 80       16.0  48.0       95.0  69.0  73.000
# 85       16.5  77.5       48.0  93.5  76.000
# 89       17.0  58.0       54.0  87.0  72.000
# 91       16.0  72.0       48.0  55.0  66.500
# 94       16.0  95.0       56.0  96.0  85.250
# 96       17.0  68.5       65.0  68.5  74.500
# 99       16.0  89.0       70.0  76.5  83.625

# %%
df.groupby('age').mean(numeric_only=True)
# Out:
#        physics       math  chemistry        art  grade
# age
# 16   75.000000  75.272727  69.727273  75.000000  73.75
# 17   74.777778  76.555556  71.555556  70.111111  73.25

# %%
df.groupby('class').agg({'physics': ['min', 'max'], 'math': ['min', 'max'], 'chemistry' : ['min', 'max'], 'art': ['min', 'max']})
# Out:
#         physics     math     chemistry     art
#             min max  min max       min max min max
# class
# Class A      42  99   48  96        51  97  66  96
# Class B      45  85   58  85        45  80  43  97
# Class C      78  99   63  99        43  92  44  80

# %%
df.boxplot()
plt.show()

# %%
df.hist(column='grade')
plt.show()

# %%
for label, content in df.items():
    print(f'label: {label}')
    print(f'content:\n{content}', sep='\n')
# Out:
# label: name
# content:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4         Eve
# 5       Frank
# 6       Grace
# 7      Hannah
# 8         Ivy
# 9        Jack
# 10      Kevin
# 11       Lily
# 12       Mike
# 13       Nina
# 14      Oscar
# 15       Paul
# 16     Quincy
# 17       Rita
# 18        Sam
# 19       Tina
# Name: name, dtype: object
# label: age
# content:
# 0     17
# 1     17
# 2     16
# 3     16
# 4     16
# 5     16
# 6     16
# 7     17
# 8     17
# 9     17
# 10    17
# 11    16
# 12    16
# 13    17
# 14    16
# 15    16
# 16    16
# 17    16
# 18    17
# 19    17
# Name: age, dtype: int64
# label: class
# content:
# 0     Class B
# 1     Class A
# 2     Class A
# 3     Class A
# 4     Class C
# 5     Class B
# 6     Class A
# 7     Class A
# 8     Class A
# 9     Class C
# 10    Class C
# 11    Class B
# 12    Class B
# 13    Class A
# 14    Class B
# 15    Class A
# 16    Class A
# 17    Class C
# 18    Class A
# 19    Class C
# ...

# %%
df2 = pd.DataFrame([[5, 6]]*3, columns=['A', 'B'])
df2
# Out:
#    A  B
# 0  5  6
# 1  5  6
# 2  5  6

# %%
df2.ndim
# Out:
# 2

# %%
df2.shape
# Out:
# (3, 2)

# %%
df2.apply('sum') # default axis = 0 (rows)
# Out:
# A    15
# B    18
# dtype: int64

# %%
df2.apply('sum', axis=1) # axis = 1 (columns)
# Out:
# 0    11
# 1    11
# 2    11
# dtype: int64

# %%
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=False)

# %%
df2
# Out:
#    A  B
# 0  5  6
# 1  5  6
# 2  5  6

# %%
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ql/zz4g9pw96t1dpfbq235fns6c0000gn/T/ipykernel_16951/1869104152.py in ?()
# ----> 1 df2.insert(loc=0, column='Y', value= 1, allow_duplicates=False)
#
# /Applications/anaconda3/envs/gizasystemEnv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Y, already exists

# %%
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=True)

# %%
df2
# Out:
#    Y  Y  A  B
# 0  1  1  5  6
# 1  1  1  5  6
# 2  1  1  5  6

# %%
del(df2['Y'])
df2
# Out:
#    Z  A  B
# 0  8  5  6
# 1  8  5  6
# 2  8  5  6

# %%
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=True)
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=True)
df2
# Out:
#    Y  Y  Y  A  B
# 0  1  1  1  5  6
# 1  1  1  1  5  6
# 2  1  1  1  5  6

# %%
df2.drop(df2.columns[1],axis=1,inplace=True)
df2
# Out:
#    Z  A  B  T
# 0  8  5  6  2
# 1  8  5  6  2
# 2  8  5  6  2

# %%
df2
# Out:
#    Z  A  B  T
# 0  8  5  6  2
# 1  8  5  6  2
# 2  8  5  6  2

# %%
df2.insert(loc=0, column='Y', value= 1, allow_duplicates=False)
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ql/zz4g9pw96t1dpfbq235fns6c0000gn/T/ipykernel_16951/3730161713.py in ?()
# ----> 1 df2.insert(loc=0, column='Y', value= 1, allow_duplicates=False)
#       2 df2
#
# /Applications/anaconda3/envs/gizasystemEnv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ...

# %%
df2.columns = pd.Index(['X','Y','Z','A','B'])

# %%
df2
# Out:
#    X  Y  Z  A  B
# 0  1  1  8  5  6
# 1  1  1  8  5  6
# 2  1  1  8  5  6

# %%
del(df2['X'])

# %%
df2
# Out:
#    Y  Z  A  B
# 0  1  8  5  6
# 1  1  8  5  6
# 2  1  8  5  6

# %%
df2.drop('Y',axis= 1, inplace=True)

# %%
df2
# Out:
#    Y  Y  Z  A  B
# 0  1  1  8  5  6
# 1  1  1  8  5  6
# 2  1  1  8  5  6

# %%
df2.T
# Out:
#    0  1  2
# Y  1  1  1
# Y  1  1  1
# Z  8  8  8
# A  5  5  5
# B  6  6  6

# %%
df2.T.groupby(level=0).first()
# Out:
#    0  1  2
# A  5  5  5
# B  6  6  6
# Y  1  1  1
# Z  8  8  8

# %%
df2.T.groupby(level=0).first().T
# Out:
#    A  B  T  Y  Z
# 0  5  6  2  1  8
# 1  5  6  2  1  8
# 2  5  6  2  1  8

# %%
df2
# Out:
#    Y  Y  Z  A  B
# 0  3  1  8  5  6
# 1  3  1  8  5  6
# 2  3  1  8  5  6

# %%
df2.iloc[:,0]
# Out:
# 0    3
# 1    3
# 2    3
# Name: Y, dtype: int64

# %%
df2.iloc[:,1]
# Out:
# 0    1
# 1    1
# 2    1
# Name: Y, dtype: int64

# %%
df2.loc[:,'Y']
# Out:
#    Y  Y
# 0  3  1
# 1  3  1
# 2  3  1

# %%
df2 = df2.T.drop_duplicates().T
df2
# Out:
#    Y  Z  A  B
# 0  1  8  5  6
# 1  1  8  5  6
# 2  1  8  5  6

# %%
df2['T'] = df2.iloc[:,0] + df2.iloc[:,1]

# %%
df2
# Out:
#    Y  Y  Z  A  B  T
# 0  1  1  8  5  6  2
# 1  1  1  8  5  6  2
# 2  1  1  8  5  6  2

# %%
df2.T.drop_duplicates().T
# Out:
#    Y  Y  Z  A  B  T
# 0  3  1  8  5  6  4
# 1  3  1  8  5  6  4
# 2  3  1  8  5  6  4

# %%
df3 = df2['Y']+1

# %%
df3
# Out:
#    Y  Y
# 0  4  2
# 1  4  2
# 2  4  2

# %%
df3.shape
# Out:
# (3, 2)

# %%
df2
# Out:
#    Y  Y  Y  A  B
# 0  1  1  1  5  6
# 1  1  1  1  5  6
# 2  1  1  1  5  6

# %%
df2.columns.duplicated()
# Out:
# array([False,  True, False, False])

# %%
~df2.columns.duplicated()
# Out:
# array([ True, False,  True,  True])

# %%
df2.columns = pd.Series(df2.columns).where(~df2.columns.duplicated(keep='last')).fillna('') # duplicated(keep='last')
df2
# Out:
#          Y  A  B
# 0  1  1  1  5  6
# 1  1  1  1  5  6
# 2  1  1  1  5  6

# %%
df2.drop('', axis=1, inplace=True)
df2
# Out:
#    Y  A  B
# 0  1  5  6
# 1  1  5  6
# 2  1  5  6
